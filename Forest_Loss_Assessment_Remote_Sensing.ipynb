# %% [markdown]
# <a href="https://colab.research.google.com/github/p-med/CP_Parks_data_prep/blob/main/Forest_Loss_Assessment_Remote_Sensing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Forest Loss assessment on the Mbaracayu Reserve due to illegal logging, Amambay, Paraguay
# *Author: Paulo Medina*

# %%
# Import modules
import pandas as pd
import numpy as np
import geopandas as gpd
import ee
import shapely
from shapely.geometry import Point

# %%
# Get the shapefile from Google Earth Engine
ee.Authenticate()
ee.Initialize(project='webprogrammingumd')
